# %%
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools.agent_tool import AgentTool
from google.adk.tools.google_search_tool import google_search

from google.genai import types
from typing import List
from dotenv import load_dotenv
import os
from google.adk.runners import InMemoryRunner
from google.adk.plugins.logging_plugin import LoggingPlugin
from google.genai import types
import asyncio

# %%
load_dotenv()
# Out:
# True

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
def count_papers(papers: List[str]):
    """
    This function counts the number of papers in a list of strings.
    Args:
      papers: A list of strings, where each string is a research paper.
    Returns:
      The number of papers in the list.
    """
    return len(papers)

# %%
# Google Search agent
google_search_agent = LlmAgent(
    name="google_search_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="Searches for information using Google search",
    instruction="""Use the google_search tool to find information on the given topic. Return the raw search results.
    If the user asks for a list of papers, then give them the list of research papers you found and not the summary.""",
    tools=[google_search]
)

# %%
# Root agent
research_agent_with_plugin = LlmAgent(
    name="research_paper_finder_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""Your task is to find research papers and count them. 

    You MUST ALWAYS follow these steps:
    1) Find research papers on the user provided topic using the 'google_search_agent'. 
    2) Then, pass the papers to 'count_papers' tool to count the number of papers returned.
    3) Return both the list of research papers and the total number of papers.
    """,
    tools=[AgentTool(agent=google_search_agent), count_papers]
)

# %%
runner = InMemoryRunner(
    agent=research_agent_with_plugin,
    plugins=[
        LoggingPlugin()
    ]
)

# %%
response = await runner.run_debug("Find recent papers on quantum computing")
# Out:
#  ### Created new session: debug_session_id
#
# User > Find recent papers on quantum computing
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-18a7412e-8225-46ab-8859-07eaed48642e
# [logging_plugin]    Session ID: debug_session_id
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: research_paper_finder_agent
# [logging_plugin]    User Content: text: 'Find recent papers on quantum computing'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-18a7412e-8225-46ab-8859-07eaed48642e
# [logging_plugin]    Starting Agent: research_paper_finder_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-18a7412e-8225-46ab-8859-07eaed48642e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#     You MUST ALWAYS follow these steps:
#     1) Find research papers on the user provided topic using the 'google_search_agent'.
#     2) Then, pas...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Token Usage - Input: 241, Output: 21
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9f3f8ae2-e026-4f61-bbd6-519c5ee75f07
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['google_search_agent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-71a05a63-619f-4cd8-854b-a0110aa8c802
# [logging_plugin]    Arguments: {'request': 'recent papers on quantum computing'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-d0392b03-cf9b-4c4e-a0f3-9eb9b0cb3a8b
# [logging_plugin]    Session ID: 1657f7ad-ba8b-482c-ac85-d3f8f2a04aff
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: google_search_agent
# [logging_plugin]    User Content: text: 'recent papers on quantum computing'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-d0392b03-cf9b-4c4e-a0f3-9eb9b0cb3a8b
# [logging_plugin]    Starting Agent: google_search_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-d0392b03-cf9b-4c4e-a0f3-9eb9b0cb3a8b
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    System Instruction: 'Use the google_search tool to find information on the given topic. Return the raw search results.
#     If the user asks for a list of papers, then give them the list of research papers you found and no...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    Content: text: 'Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus include improving qubit stability and coherence times, developin...'
# [logging_plugin]    Token Usage - Input: 85, Output: 641
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 69f1d71b-2b18-4cbb-96e9-02d424d32b72
# [logging_plugin]    Author: google_search_agent
# [logging_plugin]    Content: text: 'Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus include improving qubit stability and coherence times, developin...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-d0392b03-cf9b-4c4e-a0f3-9eb9b0cb3a8b
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-d0392b03-cf9b-4c4e-a0f3-9eb9b0cb3a8b
# [logging_plugin]    Final Agent: google_search_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-71a05a63-619f-4cd8-854b-a0110aa8c802
# [logging_plugin]    Result: Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus include improving qubit stability and coherence times, developing efficient quantum algorithms for various problems, and exploring hybrid quantum-classical approach...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9ba83e6e-f404-4b29-b485-83cfee1b2240
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['google_search_agent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#     You MUST ALWAYS follow these steps:
#     1) Find research papers on the user provided topic using the 'google_search_agent'.
#     2) Then, pas...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Token Usage - Input: 895, Output: 614
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 46b2c4b4-8163-4ab7-bb0b-6b249c1d60dc
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['count_papers']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-08c5eae8-669b-4718-8456-05585037290d
# [logging_plugin]    Arguments: {'papers': ['Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus include improving qubit stability and coherence times, developing efficient quantum algorithms for various problems, and exploring hybrid quantum-class...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-08c5eae8-669b-4718-8456-05585037290d
# [logging_plugin]    Result: 5
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 37982995-ece5-41dc-9944-15f399810730
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['count_papers']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#     You MUST ALWAYS follow these steps:
#     1) Find research papers on the user provided topic using the 'google_search_agent'.
#     2) Then, pas...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: text: 'Here are the recent papers on quantum computing I found:
#
# 1.  Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus in...'
# [logging_plugin]    Token Usage - Input: 1524, Output: 563
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bf961ab2-ac1b-4a06-b681-ea699f29bec9
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: text: 'Here are the recent papers on quantum computing I found:
#
# 1.  Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus in...'
# [logging_plugin]    Final Response: True
# research_paper_finder_agent > Here are the recent papers on quantum computing I found:
#
# 1.  Recent research in quantum computing in 2024 and 2025 covers advancements in hardware, algorithms, and applications. Key areas of focus include improving qubit stability and coherence times, developing efficient quantum algorithms for various problems, and exploring hybrid quantum-classical approaches.
# 2.  Notable publications and research areas include: *Hardware Advancements*: Princeton engineers have developed a superconducting qubit with a significantly extended lifetime, using a tantalum-silicon design to reduce energy loss. This breakthrough could enable larger and more stable quantum processors. Research on scaling and networking modular photonic quantum computers has demonstrated practical scalability in photonic quantum computing. The development of topological qubits is being explored to enhance error correction by making qubits less susceptible to environmental disturbances.
# 3.  *Quantum Algorithms and Software*: Papers from Spring 2024 highlighted advancements in algorithms for preparing ground states, simulating complex systems, and performing fast quantum integer multiplication. Winter 2025 research includes papers on optimizing instantaneous quantum polynomial circuits, improving quantum phase estimation, and developing efficient quantum simulation algorithms. Google Quantum AI has published research on learning shallow quantum circuits, demonstrating dynamic surface codes for quantum error correction, and developing optimization algorithms like decoded quantum interferometry (DQI). There's ongoing work on optimizing quantum circuit layout for wind farms and comparing classical and quantum algorithms for specific problems.
# 4.  *Applications and Challenges*: Quantum computing's potential applications span diverse fields such as materials science, drug design, finance, and artificial intelligence. Research is exploring hybrid quantum-classical models for machine learning, with efforts to scale generative quantum machine learning to larger qubit systems. A significant challenge remains in achieving scalability, resource optimization, and robust error correction. The development of post-quantum cryptography is crucial to secure data against future quantum computers. A literature survey in 2024 reviewed advancements, non-standard architectures, and applications in material sciences, while also identifying remaining challenges like scalability and resource optimization.
# 5.  *Key Publications and Journals*: "Quantum Computing: Vision and Challenges" (arXiv, updated April 2025) discusses hardware, software, and the future of quantum technology. The journal *Quantum Rep.* published 14 articles in its March 2025 issue, covering topics from economic models to quantum circuit optimization. The *Journal of Quantum Computing* publishes research on various aspects of the field, including quantum algorithms, machine learning, and cryptography. The PennyLane blog features lists of top quantum algorithms papers for Spring 2024 and Winter 2025. Articles in *Nature* have reported significant breakthroughs, such as the extended qubit lifetimes achieved by Princeton engineers.
#
# There are a total of 5 papers.
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-18a7412e-8225-46ab-8859-07eaed48642e
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-18a7412e-8225-46ab-8859-07eaed48642e
# [logging_plugin]    Final Agent: research_paper_finder_agent
