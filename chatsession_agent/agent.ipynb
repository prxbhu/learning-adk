# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")
        
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"  # Model

# %%
# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# %%
# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# %%
# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

# %%
print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %%
await run_session(
    runner,
    [
        "Hi, I am Sam! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Sam! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam! 😊

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me what the capital of the United States is, and then you asked me what your name is.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Sam!

# %%
#Persistent memory using a database (e.g., SQLite)

# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# %%
# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

# %%
print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %%
await run_session(
    runner,
    ["Hi, I am Sam! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Sam! What is the capital of the United States?
# gemini-2.5-flash-lite >  It's nice to meet you, Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %%
#new session, so no prior context
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I'm sorry, but I don't know your name. I'm a text chatbot and I don't have access to any personal information about you.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, including your name. I am a text chatbot and do not store any user data."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "It\'s nice to meet you, Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I\'m sorry, but I don\'t know your name. I\'m a text chatbot and I don\'t have access to any personal information about you."}], "role": "model"}')

# %%
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)
# Out:
# <ipython-input-30-d5ef9779993d>:5: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  Here's a summary of recent AI news in healthcare, focusing on key trends and developments:
#
# **1. Advancements in Diagnostics and Imaging:**
#
# *   **Improved Accuracy in Medical Imaging:** AI algorithms are continuing to demonstrate remarkable accuracy in detecting subtle anomalies in X-rays, CT scans, MRIs, and other medical images. This is leading to earlier and more precise diagnoses for conditions like cancer, diabetic retinopathy, and cardiovascular diseases.
# *   **AI-Powered Pathology:** AI is being used to analyze digital pathology slides, assisting pathologists in identifying cancerous cells and grading tumors with increased speed and consistency.
# *   **Personalized Screening:** AI is helping to tailor screening recommendations based on an individual's risk factors, potentially optimizing when and how often certain screenings should occur.
#
# **2. Drug Discovery and Development Acceleration:**
#
# *   **Predictive Modeling for Drug Efficacy:** AI is being employed to predict the potential success of drug candidates, identify novel drug targets, and design new molecules, significantly speeding up the traditionally long and expensive drug development process.
# *   **Clinical Trial Optimization:** AI can help identify suitable patient populations for clinical trials, predict patient recruitment rates, and analyze trial data more efficiently.
#
# **3. AI in Patient Care and Management:**
#
# *   **Personalized Treatment Plans:** AI is moving beyond broad recommendations to offer highly individualized treatment plans by analyzing a patient's genetic makeup, medical history, lifestyle, and response to previous treatments.
# *   **Virtual Health Assistants and Chatbots:** AI-powered chatbots are increasingly being used for patient triage, appointment scheduling, answering frequently asked questions, and providing basic health information, freeing up healthcare professionals for more complex tasks.
# *   **Remote Patient Monitoring:** AI can analyze data from wearable devices and other sensors to monitor patients with chronic conditions remotely, alerting healthcare providers to potential issues before they become critical.
# *   **Predictive Analytics for Patient Outcomes:** AI models are being developed to predict patient readmission risks, identify individuals at high risk of developing certain diseases, and forecast disease outbreaks.
#
# **4. Regulatory and Ethical Considerations Gaining Traction:**
#
# *   **Focus on AI Explainability (XAI):** As AI becomes more integrated into clinical decision-making, there's a growing demand for AI models that can explain their reasoning. This is crucial for building trust among clinicians and ensuring accountability.
# *   **Data Privacy and Security:** With the use of vast amounts of patient data, ensuring robust data privacy and security measures remains a paramount concern, leading to stricter regulations and ethical guidelines.
# *   **Bias Mitigation in AI Algorithms:** Ongoing efforts are focused on identifying and mitigating biases in AI algorithms that could lead to disparities in care for certain demographic groups.
#
# **5. Emerging Trends and Future Outlook:**
#
# *   **Generative AI for Medical Content Creation:** Generative AI is being explored for tasks like summarizing medical literature, drafting clinical notes, and even generating synthetic medical data for training purposes.
# *   **AI for Mental Health Support:** AI is being used to develop tools for early detection of mental health conditions, personalized therapy recommendations, and providing accessible support through chatbots.
# *   **Integration with Electronic Health Records (EHRs):** Seamless integration of AI tools into existing EHR systems is a key focus to ensure widespread adoption and practical application in daily clinical workflows.
#
# **Key Challenges and Ongoing Discussions:**
#
# *   **Data Availability and Quality:** Access to large, diverse, and high-quality datasets remains a bottleneck for training robust AI models.
# *   **Clinical Validation and Trust:** Rigorous clinical validation is essential to ensure the safety and efficacy of AI tools before widespread adoption. Building trust among healthcare professionals is also critical.
# *   **Workforce Training and Adaptation:** Healthcare professionals need training and education to effectively understand, utilize, and collaborate with AI technologies.
#
# Overall, the field of AI in healthcare is rapidly evolving, with a strong emphasis on improving diagnostic accuracy, accelerating drug discovery, enhancing patient care, and addressing the ethical and regulatory challenges associated with these powerful technologies.

# %%
# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, there are many exciting new developments in drug discovery, largely driven by the increasing sophistication and application of Artificial Intelligence (AI) and machine learning (ML). Here are some of the key areas and recent advancements:
#
# **1. AI-Powered Target Identification and Validation:**
#
# *   **Genomic and Multi-omics Data Analysis:** AI is revolutionizing the way we analyze massive datasets from genomics, proteomics, transcriptomics, and metabolomics. By identifying complex patterns and relationships, AI can pinpoint novel disease targets that were previously overlooked by traditional methods.
# *   **Network Biology and Systems Thinking:** AI models can analyze biological networks to understand how different molecules and pathways interact, leading to a more holistic understanding of disease mechanisms and the identification of more effective intervention points.
# *   **Predicting Target "Druggability":** AI is being used to predict which identified targets are most likely to be successfully modulated by small molecules or biologics, saving significant resources by focusing on promising candidates.
#
# **2. Accelerated Molecule Design and Optimization:**
#
# *   **Generative AI for De Novo Drug Design:** This is a major breakthrough. Generative AI models (like GANs and VAEs) can now design novel molecular structures from scratch with desired properties, such as high binding affinity to a target, good ADMET (Absorption, Distribution, Metabolism, Excretion, Toxicity) profiles, and synthetic feasibility. This moves beyond simply screening existing libraries.
# *   **Predictive ADMET Modeling:** AI is improving the accuracy of predicting how a drug candidate will behave in the body (its ADMET properties) early in the discovery process. This helps to filter out compounds likely to fail due to toxicity or poor pharmacokinetics, reducing costly late-stage failures.
# *   **Optimizing Lead Compounds:** AI can suggest modifications to existing "lead" compounds to improve their efficacy, reduce side effects, and enhance their suitability for further development.
#
# **3. Revolutionizing Preclinical and Clinical Trials:**
#
# *   **In Silico Screening and Virtual Trials:** AI allows for massive virtual screening of compound libraries against targets, greatly expanding the search space. In some cases, AI is being used to model the outcomes of clinical trials virtually, helping to refine trial design and predict potential success.
# *   **Biomarker Discovery:** AI can analyze patient data to identify biomarkers that predict drug response, enabling more targeted patient selection for clinical trials and personalized medicine approaches.
# *   **Repurposing Existing Drugs:** AI can sift through vast amounts of scientific literature and clinical data to identify existing drugs that might be effective for new indications, offering a faster and less risky path to new therapies.
#
# **4. Advancements in Specific Therapeutic Areas:**
#
# *   **Oncology:** AI is making significant strides in identifying new cancer targets, designing personalized cancer therapies, and predicting patient response to immunotherapy.
# *   **Neuroscience:** AI is being used to understand complex neurological diseases like Alzheimer's and Parkinson's and to design novel treatments for these challenging conditions.
# *   **Infectious Diseases:** AI is crucial in identifying potential antiviral and antibacterial agents and predicting the evolution of drug resistance.
#
# **Examples of Recent Progress:**
#
# *   **Insilico Medicine:** This company has been a leader in using generative AI to discover novel drug candidates. They have advanced several AI-discovered drugs into clinical trials, including for idiopathic pulmonary fibrosis.
# *   **Exscientia:** Another prominent player, Exscientia uses AI to design novel drug molecules and has advanced multiple AI-designed drugs into human clinical trials.
# *   **Recursion Pharmaceuticals:** They use AI and automation to map human cellular structures and identify potential drug candidates for various diseases.
#
# **Key Trends to Watch:**
#
# *   **Integration of Multiple AI Modalities:** Combining different AI techniques (e.g., generative models with predictive models) for more comprehensive drug discovery.
# *   **Explainable AI (XAI) in Drug Discovery:** As AI plays a more critical role, understanding "why" an AI model suggests a particular molecule or target will become increasingly important for regulatory approval and scientific validation.
# *   **AI-Driven Synthesis Planning:** AI is also being used to design efficient and cost-effective synthetic routes for newly discovered molecules.
#
# While AI is not a magic bullet, it is undeniably transforming drug discovery from a largely trial-and-error process to a more data-driven, predictive, and efficient endeavor. This promises to accelerate the delivery of new and better treatments to patients.

# %%
# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're likely referring to the second major development I mentioned in the previous response, which was:
#
# **2. Accelerated Molecule Design and Optimization**
#
# This area is absolutely crucial because it addresses the "how" of creating new medicines. Once a target is identified, the next monumental task is to find or create a molecule that can interact with that target in a beneficial way. AI is dramatically speeding up and improving this process.
#
# Let's break down the key aspects:
#
# *   **Generative AI for De Novo Drug Design:**
#     *   **What it means:** "De novo" means "from the beginning." Instead of sifting through massive existing libraries of molecules, generative AI can *create entirely new molecular structures* that have never been synthesized before.
#     *   **How it works:** Think of it like an artist who has studied countless paintings and understands the principles of color, composition, and style. Generative AI models are trained on vast datasets of known molecules and their properties. They then learn the underlying "rules" of molecular chemistry and can generate novel molecules that are predicted to have desired characteristics.
#     *   **Key Technologies:** Common generative models include Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs). These models learn to generate data (in this case, molecular structures) that resembles the training data but also exhibits novelty.
#     *   **Desired Characteristics:** These AI models are designed to generate molecules that are:
#         *   **Potent:** Bind strongly to the target protein.
#         *   **Selective:** Bind primarily to the intended target, minimizing off-target effects and side effects.
#         *   **Synthesizable:** Chemically feasible to create in a laboratory.
#         *   **Have good ADMET properties:** (discussed below).
#     *   **Impact:** This drastically expands the chemical space that can be explored, potentially uncovering completely new classes of drugs that would never have been found through traditional screening.
#
# *   **Predictive ADMET Modeling:**
#     *   **What it means:** ADMET stands for **A**bsorption, **D**istribution, **M**etabolism, **E**xcretion, and **T**oxicity. These are the critical pharmacokinetic and pharmacodynamic properties that determine how a drug behaves in the human body.
#     *   **Why it's important:** A molecule might bind perfectly to its target (high potency), but if it's toxic, cannot be absorbed, gets metabolized too quickly, or is rapidly excreted, it will never make it as a viable drug.
#     *   **How AI helps:** AI/ML models can be trained on data from existing drugs and compounds that have undergone preclinical and clinical testing. These models learn the complex relationships between a molecule's chemical structure and its ADMET profile.
#     *   **Benefits:**
#         *   **Early Failure Prediction:** AI can flag molecules with predicted poor ADMET properties *very early* in the discovery process, saving immense time and resources by preventing them from moving forward.
#         *   **Prioritization:** It helps researchers prioritize molecules that are more likely to succeed in later stages.
#         *   **Design Guidance:** AI can provide feedback on *how* to modify a molecule to improve its ADMET profile.
#     *   **Impact:** This reduces the attrition rate of drug candidates, which is notoriously high in pharmaceutical R&D.
#
# *   **Optimizing Lead Compounds:**
#     *   **What it means:** "Lead compounds" are promising molecules that have demonstrated initial efficacy against a target but may still have flaws (e.g., not potent enough, some side effects, difficult to formulate).
#     *   **How AI helps:** AI can analyze the structure-activity relationship (SAR) – how small changes in a molecule's structure affect its activity and properties. It can then suggest specific chemical modifications to improve the lead compound, making it a more viable drug candidate.
#     *   **Impact:** This iterative process of AI-guided modification refines a promising molecule into a drug candidate with optimal efficacy, safety, and pharmacokinetic properties.
#
# **In essence, AI is empowering scientists to:**
#
# *   **Design entirely new drugs from scratch** rather than just searching for existing ones.
# *   **Predict and mitigate potential problems** (like toxicity or poor absorption) *before* investing heavily in synthesis and testing.
# *   **Iteratively improve promising candidates** to create the best possible version of a drug.
#
# This acceleration in molecule design and optimization is a cornerstone of modern AI-driven drug discovery, promising to bring new therapies to patients much faster and more efficiently than ever before.

# %%
# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Turn 4
# ----> 2 await run_session(
#       3     research_runner_compacting,
#       4     "Who are the main companies involved in that?",
#       5     "compaction_demo",
#       6 )
#
# Cell In[14], line 35, in run_session(runner_instance, user_queries, session_name)
#      32 query = types.Content(role="user", parts=[types.Part(text=query)])
#      34 # Stream the agent's response asynchronously
# ---> 35 async for event in runner_instance.run_async(
#      36     user_id=USER_ID, session_id=session.id, new_message=query
#      37 ):
#      38     # Check if the event contains valid content
#      39     if event.content and event.content.parts:
#      40         # Filter out empty or "None" responses before printing
#      41         if (
#      42             event.content.parts[0].text != "None"
#      43             and event.content.parts[0].text
#      44         ):
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/runners.py:443, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     436       asyncio.create_task(
#     437           _run_compaction_for_sliding_window(
#     438               self.app, session, self.session_service
#     439           )
#     440       )
#     442 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 443   async for event in agen:
#     444     yield event
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/runners.py:427, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     417       yield event
#     419 async with Aclosing(
#     420     self._exec_with_plugin(
#     421         invocation_context=invocation_context,
#    (...)    425     )
#     426 ) as agen:
# --> 427   async for event in agen:
#     428     yield event
#     429 # Run compaction after all events are yielded from the agent.
#     430 # (We don't compact in the middle of an invocation, we only compact at the end of an invocation.)
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/runners.py:653, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     650 else:
#     651   # Step 2: Otherwise continue with normal execution
#     652   async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 653     async for event in agen:
#     654       if not event.partial:
#     655         if self._should_append_event(event, is_live_call):
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/runners.py:416, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     414 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     415   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 416     async for event in agen:
#     417       yield event
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:435, in LlmAgent._run_async_impl(self, ctx)
#     433 should_pause = False
#     434 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 435   async for event in agen:
#     436     self.__maybe_save_output_to_state(event)
#     437     yield event
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:356, in BaseLlmFlow.run_async(self, invocation_context)
#     354 last_event = None
#     355 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 356   async for event in agen:
#     357     last_event = event
#     358     yield event
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:375, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     371 # Preprocess before calling the LLM.
#     372 async with Aclosing(
#     373     self._preprocess_async(invocation_context, llm_request)
#     374 ) as agen:
# --> 375   async for event in agen:
#     376     yield event
#     377 if invocation_context.end_invocation:
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:465, in BaseLlmFlow._preprocess_async(self, invocation_context, llm_request)
#     461 for processor in self.request_processors:
#     462   async with Aclosing(
#     463       processor.run_async(invocation_context, llm_request)
#     464   ) as agen:
# --> 465     async for event in agen:
#     466       yield event
#     468 # Run processors for tools.
#     469
#     470 # We may need to wrap some built-in tools if there are other tools
#     471 # because the built-in tools cannot be used together with other tools.
#     472 # TODO(b/448114567): Remove once the workaround is no longer needed.
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/contents.py:50, in _ContentLlmRequestProcessor.run_async(self, invocation_context, llm_request)
#      46 instruction_related_contents = llm_request.contents
#      48 if agent.include_contents == 'default':
#      49   # Include full conversation history
# ---> 50   llm_request.contents = _get_contents(
#      51       invocation_context.branch,
#      52       invocation_context.session.events,
#      53       agent.name,
#      54   )
#      55 else:
#      56   # Include current turn context only (no conversation history)
#      57   llm_request.contents = _get_current_turn_contents(
#      58       invocation_context.branch,
#      59       invocation_context.session.events,
#      60       agent.name,
#      61   )
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/contents.py:354, in _get_contents(current_branch, events, agent_name)
#     351   raw_filtered_events.append(event)
#     353 if has_compaction_events:
# --> 354   events_to_process = _process_compaction_events(raw_filtered_events)
#     355 else:
#     356   events_to_process = raw_filtered_events
#
# File ~/Documents/adk/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/contents.py:265, in _process_compaction_events(events)
#     262 if event.actions and event.actions.compaction:
#     263   compaction = event.actions.compaction
#     264   if (
# --> 265       compaction.start_timestamp is not None
#     266       and compaction.end_timestamp is not None
#     267   ):
#     268     # Create a new event for the compacted summary.
#     269     new_event = Event(
#     270         timestamp=compaction.end_timestamp,
#     271         author='model',
#    (...)    275         actions=event.actions,
#     276     )
#     277     # Prepend to maintain chronological order in the final list.
#
# AttributeError: 'dict' object has no attribute 'start_timestamp'

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='0764433e-b06d-4d1d-bb3f-564941784802' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1764053759.789202, 'end_timestamp': 1764053809.846532, 'compacted_content': {'parts': [{'media_resolution': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_call': None, 'function_response': None, 'inline_data': None, 'text': 'The user inquired about the latest news in AI in healthcare. The AI agent provided a comprehensive overview covering advancements in diagnostics and imaging, drug discovery and development acceleration, AI in patient care and management, regulatory and ethical considerations, and emerging trends. Key challenges such as data availability, clinical validation, and workforce training were also highlighted.\n\nFollowing up, the user asked for more details on drug discovery developments. The AI agent elaborated on several key areas, including AI-powered target identification, accelerated molecule design and optimization, and revolutionizing preclinical and clinical trials. Specific examples of companies like Insilico Medicine and Exscientia were mentioned.\n\nThe user then requested more information about the "second development" from the drug discovery discussion. The AI agent clarified this referred to **Accelerated Molecule Design and Optimization**. The agent explained this in detail, focusing on:\n\n*   **Generative AI for De Novo Drug Design:** How AI can create entirely new molecular structures from scratch with desired properties.\n*   **Predictive ADMET Modeling:** How AI predicts Absorption, Distribution, Metabolism, Excretion, and Toxicity of potential drugs early in the process to prevent failures.\n*   **Optimizing Lead Compounds:** How AI suggests modifications to promising molecules to improve their efficacy, safety, and pharmacokinetic properties.\n\nThe interaction concluded with the AI agent emphasizing how these AI capabilities are enabling the design of new drugs from scratch, proactive mitigation of potential issues, and iterative improvement of drug candidates, ultimately accelerating the delivery of new therapies.\n\n**Key Decisions/Information:**\n*   The user received a broad overview of AI in healthcare and specific details on AI\'s role in drug discovery.\n*   The AI agent successfully identified and elaborated on the user\'s specific interest in "Accelerated Molecule Design and Optimization."\n\n**Unresolved Questions/Tasks:**\n*   None. The conversation was a focused information exchange.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='7a5609de-493f-40cd-9cb1-95564937aa7e' timestamp=1764053819.101625

# %%
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# %%
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}

# %%
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# %%
# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# %%
# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

# %%
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Sam. I'm from Poland.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing well, thank you for asking. I can't recall your name just yet. If you'd like to tell me, I can remember it for you.
#
# User > My name is Sam. I'm from Poland.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  It's nice to meet you, Sam! I'll save your name and country.
#
# gemini-2.5-flash-lite >  I have saved your information. How can I help you today?
#
# User > What is my name? Which country am I from?
# gemini-2.5-flash-lite >  Your name is Sam and you are from Poland.

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Sam', 'user:country': 'Poland'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I can't recall your name just yet. Can you remind me?
